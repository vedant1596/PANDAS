# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\hp\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\hp\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)
# notebook 5.4.0 requires ipykernel, which is not installed.
# jupyter 1.0.0 requires ipykernel, which is not installed.
# jupyter-console 5.2.0 requires ipykernel, which is not installed.
# ipywidgets 7.1.1 requires ipykernel>=4.5.1, which is not installed.

# %%
from random import uniform
import pandas as pd
import numpy as np
import csv
import random
import matplotlib.pyplot as plt
import requests as req
import json
import seaborn as sns
from datetime import datetime as dt
import os,sys
from scipy import stats
from citipy import citipy as cp

# %%
#Grab list of cities based on coordinates from citipy
citylist = []
count = 0
dup = 'no'

for x in range(-90,90):
    for y in range(-180,180):
        city = cp.nearest_city(x, y)
        citdict = {}
        citdict['city'] = city.city_name
        citdict['country'] = city.country_code
        citdict['lat'] = x
        citdict['long'] = y
        if len(citylist) == 0:
            citylist.append(citdict)
            count+=1
            continue
        else:
            #Get rid of duplicates
            for city in citylist:
                if city['city'] == citdict['city']:
                    dup = 'yes'
        if dup == 'no':
            citylist.append(citdict)
            count+=1
        else:
            dup = 'no'

# %%
import requests as req
import json

# %%
citypd = pd.DataFrame({
    'city': [x['city'] for x in citylist],
    'country': [x['country'] for x in citylist],
})

citypd.head()

samplecity = citypd.sample(500)

# %%
samplecity
# Out:
#                           city country
# 2252                     apomu      ng
# 6685               makkaveyevo      ru
# 4841          south lake tahoe      us
# 2065                  semporna      my
# 7627                  vilyuysk      ru
# 7908                 upernavik      gl
# 2087                    kourou      gf
# 4774                   khorion      gr
# 5837            little current      ca
# 579                    navirai      br
# 2724                   kracheh      kh
# 5877                    zagreb      hr
# 533                     calama      cl
# 7885                     kharp      ru
# 2292                phan thiet      vn
# 3553             doctor arroyo      mx
# 6938                     suzun      ru
# 6671                  kaa-khem      ru
# 3849                    qidong      cn
# 315                  springbok      za
# 5499                    stolac      ba
# 6435                strathmore      ca
# 1618                     uvira      cd
# 2789                      bara      sd
# 7482                     aldan      ru
# 2846                     kayes      ml
# 1577                   el alto      pe
# 3269                  zacatlan      mx
# 2011             manuk mangkaw      ph
# 4982                 millville      us
# ...                        ...     ...
# 5495  san benedetto del tronto      it
# 5046                   navabad      tj
# 1938                    paidha      ug
# 716                   charagua      bo
# 7471                    turtas      ru
# 5789                baruun-urt      mn
# 3600                   kaiyuan      cn
# 1526               campo maior      br
# 6836              zlatoustovsk      ru
# 6528                    ulagan      ru
# 5337         elk grove village      us
# 5940                  enumclaw      us
# 7390         zheleznodorozhnyy      ru
# 2395           san benito abad      co
# 956                 pedra azul      br
# 6944                  kommunar      ru
# 2088                   cayenne      gf
# 267                villa maria      ar
# 7020                   stupino      ru
# 2963                   mangrol      in
# 5181                   fengrun      cn
# 174        veinticinco de mayo      ar
# 7245     ilinskoye-khovanskoye      ru
# 3663                   ahraura      in
# 5795               shuangcheng      cn
# 7150            nizhniy ufaley      ru
# 393                cerro largo      br
# 2562                  petatlan      mx
# 4966                   gardner      us
# 4335                      kusk      af
#
# [500 rows x 2 columns]

# %%
apikey ="c766361480e700339d666a1c2a863033"
 
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
count = 0
samplecity['latitude'] = ""
samplecity['longitude'] = ""
samplecity['temperature'] = ""
samplecity['humidity'] = ""
samplecity['cloudiness'] = ""
samplecity['wind_speed'] = ""

for index,row in samplecity.iterrows():
    count+= 1
    query_url = url + "appid=" + apikey + "&units=" + units + "&q=" + row['city']
    try:
        weather_response = req.get(query_url)
        cityweather = weather_response.json()
#         print(cityweather)
        samplecity.set_value(index, "latitude", int(cityweather['coord']['lat']))
        samplecity.set_value(index, "longitude", int(cityweather['coord']['lat']))
        samplecity.set_value(index, "temperature", int(cityweather['main']['temp']))
        samplecity.set_value(index, "humidity", int(cityweather['main']['humidity']))
        samplecity.set_value(index, "cloudiness", int(cityweather['clouds']['all']))
        samplecity.set_value(index, "wind_speed", int(cityweather['wind']['speed']))
    except:
        print(f"No data for this city: {row['city']}")
    print(f"This is city#: {count}")
    print(f"This is: {row['city']}" )
    print(f"This is the requested URL: {query_url}")
# Out:
# C:\Users\HP\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\HP\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\HP\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\HP\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\HP\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\HP\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# This is city#: 1
# This is: apomu
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=apomu
# This is city#: 2
# This is: makkaveyevo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=makkaveyevo
# This is city#: 3
# This is: south lake tahoe
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=south lake tahoe
# This is city#: 4
# This is: semporna
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=semporna
# This is city#: 5
# This is: vilyuysk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=vilyuysk
# This is city#: 6
# This is: upernavik
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=upernavik
# This is city#: 7
# This is: kourou
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kourou
# No data for this city: khorion
# This is city#: 8
# This is: khorion
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=khorion
# This is city#: 9
# This is: little current
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=little current
# This is city#: 10
# This is: navirai
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=navirai
# No data for this city: kracheh
# This is city#: 11
# This is: kracheh
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kracheh
# This is city#: 12
# This is: zagreb
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=zagreb
# This is city#: 13
# This is: calama
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=calama
# This is city#: 14
# This is: kharp
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kharp
# This is city#: 15
# This is: phan thiet
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=phan thiet
# This is city#: 16
# This is: doctor arroyo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=doctor arroyo
# This is city#: 17
# This is: suzun
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=suzun
# This is city#: 18
# This is: kaa-khem
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kaa-khem
# This is city#: 19
# This is: qidong
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=qidong
# This is city#: 20
# This is: springbok
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=springbok
# This is city#: 21
# This is: stolac
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=stolac
# This is city#: 22
# This is: strathmore
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=strathmore
# This is city#: 23
# This is: uvira
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=uvira
# This is city#: 24
# This is: bara
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=bara
# This is city#: 25
# This is: aldan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=aldan
# This is city#: 26
# This is: kayes
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kayes
# This is city#: 27
# This is: el alto
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=el alto
# This is city#: 28
# This is: zacatlan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=zacatlan
# This is city#: 29
# This is: manuk mangkaw
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=manuk mangkaw
# This is city#: 30
# This is: millville
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=millville
# This is city#: 31
# This is: nanaimo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=nanaimo
# This is city#: 32
# This is: hebi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=hebi
# This is city#: 33
# This is: canutama
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=canutama
# No data for this city: asfi
# This is city#: 34
# This is: asfi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=asfi
# This is city#: 35
# This is: tongliao
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=tongliao
# This is city#: 36
# This is: rupert
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=rupert
# This is city#: 37
# This is: sierra vista
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=sierra vista
# No data for this city: bafra
# This is city#: 38
# This is: bafra
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=bafra
# This is city#: 39
# This is: truth or consequences
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=truth or consequences
# This is city#: 40
# This is: ishim
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=ishim
# This is city#: 41
# This is: santa maria del oro
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=santa maria del oro
# This is city#: 42
# This is: bolgar
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=bolgar
# This is city#: 43
# This is: sechura
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=sechura
# This is city#: 44
# This is: gornoye loo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=gornoye loo
# This is city#: 45
# This is: krasnyy oktyabr
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=krasnyy oktyabr
# No data for this city: teotitlan
# This is city#: 46
# This is: teotitlan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=teotitlan
# This is city#: 47
# This is: humaita
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=humaita
# This is city#: 48
# This is: san agustin acasaguastlan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=san agustin acasaguastlan
# This is city#: 49
# This is: saint-francois
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=saint-francois
# No data for this city: nam tha
# This is city#: 50
# This is: nam tha
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=nam tha
# This is city#: 51
# This is: oruro
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=oruro
# This is city#: 52
# This is: singarayakonda
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=singarayakonda
# This is city#: 53
# This is: jvari
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=jvari
# No data for this city: bababe
# This is city#: 54
# This is: bababe
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=bababe
# This is city#: 55
# This is: bukama
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=bukama
# No data for this city: el balyana
# This is city#: 56
# This is: el balyana
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=el balyana
# This is city#: 57
# This is: charters towers
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=charters towers
# This is city#: 58
# This is: kushiro
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kushiro
# This is city#: 59
# This is: saraland
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=saraland
# This is city#: 60
# This is: soldotna
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=soldotna
# This is city#: 61
# This is: alihe
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=alihe
# This is city#: 62
# This is: mildura
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=mildura
# This is city#: 63
# This is: sukabumi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=sukabumi
# This is city#: 64
# This is: pella
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=pella
# This is city#: 65
# This is: mitha tiwana
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=mitha tiwana
# This is city#: 66
# This is: nanyamba
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=nanyamba
# This is city#: 67
# This is: ligayan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=ligayan
# This is city#: 68
# This is: yangjiang
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=yangjiang
# This is city#: 69
# This is: kailua
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kailua
# This is city#: 70
# This is: heihe
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=heihe
# This is city#: 71
# This is: hope mills
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=hope mills
# This is city#: 72
# This is: ladario
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=ladario
# This is city#: 73
# This is: abong mbang
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=abong mbang
# No data for this city: bolungarvik
# This is city#: 74
# This is: bolungarvik
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=bolungarvik
# This is city#: 75
# This is: curuca
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=curuca
# This is city#: 76
# This is: key west
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=key west
# This is city#: 77
# This is: helsinki
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=helsinki
# This is city#: 78
# This is: rostovka
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=rostovka
# This is city#: 79
# This is: iraucuba
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=iraucuba
# This is city#: 80
# This is: suamico
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=suamico
# This is city#: 81
# This is: kirkwall
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kirkwall
# This is city#: 82
# This is: wroclaw
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=wroclaw
# This is city#: 83
# This is: vila do maio
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=vila do maio
# This is city#: 84
# This is: salme
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=salme
# This is city#: 85
# This is: klyuchi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=klyuchi
# This is city#: 86
# This is: varkkallai
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=varkkallai
# This is city#: 87
# This is: koulikoro
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=koulikoro
# This is city#: 88
# This is: stykkisholmur
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=stykkisholmur
# This is city#: 89
# This is: tandlianwala
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=tandlianwala
# This is city#: 90
# This is: nardaran
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=nardaran
# This is city#: 91
# This is: zwedru
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=zwedru
# This is city#: 92
# This is: brandon
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=brandon
# This is city#: 93
# This is: buritizeiro
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=buritizeiro
# This is city#: 94
# This is: road town
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=road town
# This is city#: 95
# This is: glendive
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=glendive
# This is city#: 96
# This is: xam nua
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=xam nua
# This is city#: 97
# This is: denizli
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=denizli
# This is city#: 98
# This is: hovd
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=hovd
# No data for this city: promakhoi
# This is city#: 99
# This is: promakhoi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=promakhoi
# This is city#: 100
# This is: pontivy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=pontivy
# This is city#: 101
# This is: issoudun
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=issoudun
# This is city#: 102
# This is: tuban
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=tuban
# This is city#: 103
# This is: susurluk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=susurluk
# This is city#: 104
# This is: mantua
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=mantua
# This is city#: 105
# This is: eskisehir
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=eskisehir
# No data for this city: tubruq
# This is city#: 106
# This is: tubruq
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=tubruq
# This is city#: 107
# This is: iznoski
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=iznoski
# This is city#: 108
# This is: vorchdorf
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=vorchdorf
# This is city#: 109
# This is: sinazongwe
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=sinazongwe
# This is city#: 110
# This is: sibu
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=sibu
# This is city#: 111
# This is: kuldiga
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kuldiga
# This is city#: 112
# This is: huancayo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=huancayo
# This is city#: 113
# This is: poway
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=poway
# This is city#: 114
# This is: bhuban
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=bhuban
# No data for this city: bossembele
# This is city#: 115
# This is: bossembele
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=bossembele
# This is city#: 116
# This is: haldia
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=haldia
# This is city#: 117
# This is: borgarnes
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=borgarnes
# This is city#: 118
# This is: odienne
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=odienne
# This is city#: 119
# This is: lazaro cardenas
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=lazaro cardenas
# This is city#: 120
# This is: notse
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=notse
# No data for this city: yian
# This is city#: 121
# This is: yian
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=yian
# This is city#: 122
# This is: tarko-sale
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=tarko-sale
# This is city#: 123
# This is: melita
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=melita
# This is city#: 124
# This is: tevaitoa
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=tevaitoa
# No data for this city: urulga
# This is city#: 125
# This is: urulga
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=urulga
# This is city#: 126
# This is: baculin
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=baculin
# This is city#: 127
# This is: makarov
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=makarov
# This is city#: 128
# This is: tabora
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=tabora
# This is city#: 129
# This is: along
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=along
# This is city#: 130
# This is: darlawn
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=darlawn
# This is city#: 131
# This is: qitaihe
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=qitaihe
# This is city#: 132
# This is: bose
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=bose
# This is city#: 133
# This is: zhaotong
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=zhaotong
# This is city#: 134
# This is: sambava
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=sambava
# This is city#: 135
# This is: mangit
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=mangit
# This is city#: 136
# This is: ouesso
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=ouesso
# This is city#: 137
# This is: mbaiki
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=mbaiki
# This is city#: 138
# This is: calabozo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=calabozo
# This is city#: 139
# This is: huangpi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=huangpi
# No data for this city: zolotinka
# This is city#: 140
# This is: zolotinka
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=zolotinka
# This is city#: 141
# This is: bridlington
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=bridlington
# This is city#: 142
# This is: nipawin
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=nipawin
# This is city#: 143
# This is: werneck
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=werneck
# This is city#: 144
# This is: korgen
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=korgen
# This is city#: 145
# This is: ormara
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=ormara
# No data for this city: mooi river
# This is city#: 146
# This is: mooi river
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=mooi river
# This is city#: 147
# This is: ilinge
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=ilinge
# This is city#: 148
# This is: sveti nikole
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=sveti nikole
# This is city#: 149
# This is: rorvik
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=rorvik
# This is city#: 150
# This is: anqing
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=anqing
# This is city#: 151
# This is: fushe-arrez
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=fushe-arrez
# This is city#: 152
# This is: naron
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=naron
# This is city#: 153
# This is: bima
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=bima
# This is city#: 154
# This is: joensuu
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=joensuu
# This is city#: 155
# This is: kariba
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kariba
# This is city#: 156
# This is: laem sing
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=laem sing
# This is city#: 157
# This is: general roca
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=general roca
# This is city#: 158
# This is: mankono
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=mankono
# This is city#: 159
# This is: ondjiva
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=ondjiva
# This is city#: 160
# This is: peque
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=peque
# This is city#: 161
# This is: brumunddal
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=brumunddal
# This is city#: 162
# This is: mitrofanovka
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=mitrofanovka
# This is city#: 163
# This is: benghazi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=benghazi
# This is city#: 164
# This is: igurubi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=igurubi
# This is city#: 165
# This is: temyasovo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=temyasovo
# This is city#: 166
# This is: fougamou
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=fougamou
# This is city#: 167
# This is: manosque
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=manosque
# This is city#: 168
# This is: lexington
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=lexington
# This is city#: 169
# This is: gromiljak
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=gromiljak
# This is city#: 170
# This is: manjacaze
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=manjacaze
# No data for this city: ascension
# This is city#: 171
# This is: ascension
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=ascension
# This is city#: 172
# This is: haines junction
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=haines junction
# This is city#: 173
# This is: onokhoy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=onokhoy
# This is city#: 174
# This is: cheltenham
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=cheltenham
# This is city#: 175
# This is: warrnambool
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=warrnambool
# This is city#: 176
# This is: moura
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=moura
# This is city#: 177
# This is: chaoyang
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=chaoyang
# This is city#: 178
# This is: balad
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=balad
# This is city#: 179
# This is: kingman
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kingman
# No data for this city: gumusyaka
# This is city#: 180
# This is: gumusyaka
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=gumusyaka
# This is city#: 181
# This is: price
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=price
# This is city#: 182
# This is: geelong
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=geelong
# This is city#: 183
# This is: sabang
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=sabang
# This is city#: 184
# This is: boda
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=boda
# This is city#: 185
# This is: nador
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=nador
# This is city#: 186
# This is: aracati
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=aracati
# This is city#: 187
# This is: namtsy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=namtsy
# This is city#: 188
# This is: serowe
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=serowe
# This is city#: 189
# This is: najran
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=najran
# This is city#: 190
# This is: kristianstad
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kristianstad
# This is city#: 191
# This is: rajampet
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=rajampet
# This is city#: 192
# This is: subate
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=subate
# This is city#: 193
# This is: hondo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=hondo
# This is city#: 194
# This is: makakilo city
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=makakilo city
# This is city#: 195
# This is: damghan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=damghan
# This is city#: 196
# This is: jurm
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=jurm
# This is city#: 197
# This is: balaka
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=balaka
# This is city#: 198
# This is: bhairab bazar
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=bhairab bazar
# This is city#: 199
# This is: tocache
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=tocache
# This is city#: 200
# This is: tyup
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=tyup
# This is city#: 201
# This is: ellwangen
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=ellwangen
# This is city#: 202
# This is: tornio
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=tornio
# This is city#: 203
# This is: baixa grande
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=baixa grande
# This is city#: 204
# This is: piney green
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=piney green
# This is city#: 205
# This is: san juan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=san juan
# This is city#: 206
# This is: waterlooville
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=waterlooville
# This is city#: 207
# This is: harlingen
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=harlingen
# This is city#: 208
# This is: hammerfest
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=hammerfest
# This is city#: 209
# This is: gouyave
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=gouyave
# No data for this city: alashtar
# This is city#: 210
# This is: alashtar
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=alashtar
# This is city#: 211
# This is: port arthur
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=port arthur
# This is city#: 212
# This is: fort-shevchenko
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=fort-shevchenko
# This is city#: 213
# This is: visnes
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=visnes
# This is city#: 214
# This is: uvat
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=uvat
# This is city#: 215
# This is: hanyang
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=hanyang
# This is city#: 216
# This is: chapada dos guimaraes
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=chapada dos guimaraes
# This is city#: 217
# This is: elk point
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=elk point
# This is city#: 218
# This is: beihai
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=beihai
# This is city#: 219
# This is: lichinga
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=lichinga
# This is city#: 220
# This is: adeje
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=adeje
# This is city#: 221
# This is: selfoss
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=selfoss
# This is city#: 222
# This is: coria
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=coria
# This is city#: 223
# This is: meleuz
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=meleuz
# This is city#: 224
# This is: jinchang
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=jinchang
# This is city#: 225
# This is: zelenogorskiy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=zelenogorskiy
# This is city#: 226
# This is: petrov val
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=petrov val
# This is city#: 227
# This is: bjornevatn
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=bjornevatn
# This is city#: 228
# This is: kanashevo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kanashevo
# This is city#: 229
# This is: kindersley
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kindersley
# This is city#: 230
# This is: kirzhach
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kirzhach
# This is city#: 231
# This is: abeche
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=abeche
# No data for this city: acara
# This is city#: 232
# This is: acara
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=acara
# This is city#: 233
# This is: lekoni
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=lekoni
# This is city#: 234
# This is: terney
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=terney
# This is city#: 235
# This is: parintins
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=parintins
# This is city#: 236
# This is: grafing
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=grafing
# This is city#: 237
# This is: hazleton
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=hazleton
# This is city#: 238
# This is: bandarban
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=bandarban
# This is city#: 239
# This is: shakawe
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=shakawe
# This is city#: 240
# This is: nizhniy tagil
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=nizhniy tagil
# This is city#: 241
# This is: xunchang
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=xunchang
# This is city#: 242
# This is: tchaourou
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=tchaourou
# This is city#: 243
# This is: yabrud
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=yabrud
# This is city#: 244
# This is: boyle
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=boyle
# This is city#: 245
# This is: rio tuba
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=rio tuba
# This is city#: 246
# This is: guajara
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=guajara
# This is city#: 247
# This is: gannan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=gannan
# This is city#: 248
# This is: abadan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=abadan
# This is city#: 249
# This is: quimper
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=quimper
# This is city#: 250
# This is: phek
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=phek
# This is city#: 251
# This is: tacna
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=tacna
# This is city#: 252
# This is: dzheguta
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=dzheguta
# This is city#: 253
# This is: rosarito
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=rosarito
# This is city#: 254
# This is: weyburn
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=weyburn
# This is city#: 255
# This is: luzino
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=luzino
# This is city#: 256
# This is: ortona
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=ortona
# No data for this city: sedelnikovo
# This is city#: 257
# This is: sedelnikovo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=sedelnikovo
# This is city#: 258
# This is: mercedes
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=mercedes
# This is city#: 259
# This is: aitape
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=aitape
# This is city#: 260
# This is: azare
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=azare
# No data for this city: afmadu
# This is city#: 261
# This is: afmadu
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=afmadu
# This is city#: 262
# This is: buluang
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=buluang
# This is city#: 263
# This is: pismo beach
# ...
# This is city#: 413
# This is: ritto
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=ritto
# This is city#: 414
# This is: yarensk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=yarensk
# This is city#: 415
# This is: kautokeino
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kautokeino
# This is city#: 416
# This is: birr
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=birr
# This is city#: 417
# This is: idah
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=idah
# This is city#: 418
# This is: longyearbyen
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=longyearbyen
# This is city#: 419
# This is: ivanteyevka
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=ivanteyevka
# This is city#: 420
# This is: blagoveshchensk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=blagoveshchensk
# This is city#: 421
# This is: aragarcas
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=aragarcas
# This is city#: 422
# This is: bograd
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=bograd
# This is city#: 423
# This is: tokmak
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=tokmak
# This is city#: 424
# This is: selaphum
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=selaphum
# This is city#: 425
# This is: chitral
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=chitral
# This is city#: 426
# This is: koupela
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=koupela
# This is city#: 427
# This is: palana
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=palana
# This is city#: 428
# This is: sidrolandia
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=sidrolandia
# This is city#: 429
# This is: duminichi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=duminichi
# This is city#: 430
# This is: nybro
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=nybro
# This is city#: 431
# This is: petropavl
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=petropavl
# This is city#: 432
# This is: akot
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=akot
# This is city#: 433
# This is: puchezh
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=puchezh
# This is city#: 434
# This is: velyka lepetykha
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=velyka lepetykha
# This is city#: 435
# This is: pouebo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=pouebo
# This is city#: 436
# This is: rahon
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=rahon
# This is city#: 437
# This is: kapiri mposhi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kapiri mposhi
# This is city#: 438
# This is: juegang
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=juegang
# This is city#: 439
# This is: suhbaatar
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=suhbaatar
# This is city#: 440
# This is: mangochi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=mangochi
# This is city#: 441
# This is: khuldabad
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=khuldabad
# This is city#: 442
# This is: tuljapur
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=tuljapur
# This is city#: 443
# This is: celendin
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=celendin
# This is city#: 444
# This is: saint-raymond
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=saint-raymond
# This is city#: 445
# This is: inta
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=inta
# This is city#: 446
# This is: dutse
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=dutse
# This is city#: 447
# This is: chumikan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=chumikan
# This is city#: 448
# This is: te anau
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=te anau
# This is city#: 449
# This is: praia da vitoria
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=praia da vitoria
# This is city#: 450
# This is: novobirilyussy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=novobirilyussy
# This is city#: 451
# This is: nacala
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=nacala
# This is city#: 452
# This is: mount pleasant
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=mount pleasant
# No data for this city: faridan
# This is city#: 453
# This is: faridan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=faridan
# This is city#: 454
# This is: pandan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=pandan
# This is city#: 455
# This is: penhold
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=penhold
# This is city#: 456
# This is: harbour breton
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=harbour breton
# This is city#: 457
# This is: alto araguaia
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=alto araguaia
# This is city#: 458
# This is: skibotn
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=skibotn
# No data for this city: sidi bu zayd
# This is city#: 459
# This is: sidi bu zayd
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=sidi bu zayd
# This is city#: 460
# This is: kikuchi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kikuchi
# No data for this city: galiwinku
# This is city#: 461
# This is: galiwinku
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=galiwinku
# This is city#: 462
# This is: lerik
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=lerik
# No data for this city: lephepe
# This is city#: 463
# This is: lephepe
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=lephepe
# This is city#: 464
# This is: san cristobal
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=san cristobal
# This is city#: 465
# This is: kisanga
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kisanga
# This is city#: 466
# This is: bossier city
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=bossier city
# This is city#: 467
# This is: palembang
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=palembang
# This is city#: 468
# This is: kologriv
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kologriv
# This is city#: 469
# This is: kingsland
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kingsland
# This is city#: 470
# This is: xiongyue
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=xiongyue
# This is city#: 471
# This is: san benedetto del tronto
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=san benedetto del tronto
# No data for this city: navabad
# This is city#: 472
# This is: navabad
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=navabad
# This is city#: 473
# This is: paidha
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=paidha
# This is city#: 474
# This is: charagua
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=charagua
# This is city#: 475
# This is: turtas
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=turtas
# This is city#: 476
# This is: baruun-urt
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=baruun-urt
# This is city#: 477
# This is: kaiyuan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kaiyuan
# This is city#: 478
# This is: campo maior
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=campo maior
# No data for this city: zlatoustovsk
# This is city#: 479
# This is: zlatoustovsk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=zlatoustovsk
# This is city#: 480
# This is: ulagan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=ulagan
# This is city#: 481
# This is: elk grove village
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=elk grove village
# This is city#: 482
# This is: enumclaw
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=enumclaw
# This is city#: 483
# This is: zheleznodorozhnyy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=zheleznodorozhnyy
# This is city#: 484
# This is: san benito abad
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=san benito abad
# This is city#: 485
# This is: pedra azul
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=pedra azul
# This is city#: 486
# This is: kommunar
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kommunar
# This is city#: 487
# This is: cayenne
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=cayenne
# This is city#: 488
# This is: villa maria
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=villa maria
# This is city#: 489
# This is: stupino
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=stupino
# This is city#: 490
# This is: mangrol
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=mangrol
# This is city#: 491
# This is: fengrun
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=fengrun
# This is city#: 492
# This is: veinticinco de mayo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=veinticinco de mayo
# This is city#: 493
# This is: ilinskoye-khovanskoye
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=ilinskoye-khovanskoye
# This is city#: 494
# This is: ahraura
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=ahraura
# This is city#: 495
# This is: shuangcheng
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=shuangcheng
# This is city#: 496
# This is: nizhniy ufaley
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=nizhniy ufaley
# This is city#: 497
# This is: cerro largo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=cerro largo
# This is city#: 498
# This is: petatlan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=petatlan
# This is city#: 499
# This is: gardner
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=gardner
# No data for this city: kusk
# This is city#: 500
# This is: kusk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=c766361480e700339d666a1c2a863033&units=Imperial&q=kusk

# %%
samplecity
# Out:
#                           city country latitude longitude temperature  \
# 2252                     apomu      ng        6         6          77
# 6685               makkaveyevo      ru       51        51          84
# 4841          south lake tahoe      us       38        38          61
# 2065                  semporna      my        4         4          87
# 7627                  vilyuysk      ru       63        63          55
# 7908                 upernavik      gl       72        72          30
# 2087                    kourou      gf        5         5          73
# 4774                   khorion      gr
# 5837            little current      ca       45        45          62
# 579                    navirai      br      -23       -23          67
# 2724                   kracheh      kh
# 5877                    zagreb      hr       45        45          62
# 533                     calama      cl      -22       -22          39
# 7885                     kharp      ru       66        66          30
# 2292                phan thiet      vn       10        10          89
# 3553             doctor arroyo      mx       23        23          63
# 6938                     suzun      ru       53        53          70
# 6671                  kaa-khem      ru       51        51          64
# 3849                    qidong      cn       31        31          76
# 315                  springbok      za      -29       -29          31
# 5499                    stolac      ba       43        43          67
# 6435                strathmore      ca       51        51          48
# 1618                     uvira      cd       -3        -3          66
# 2789                      bara      sd       10        10          75
# 7482                     aldan      ru       58        58          59
# 2846                     kayes      ml       14        14          74
# 1577                   el alto      pe      -16       -16          35
# 3269                  zacatlan      mx       19        19          49
# 2011             manuk mangkaw      ph        4         4          83
# 4982                 millville      us       39        39          66
# ...                        ...     ...      ...       ...         ...
# 5495  san benedetto del tronto      it       42        42          69
# 5046                   navabad      tj
# 1938                    paidha      ug        2         2          73
# 716                   charagua      bo      -19       -19          73
# 7471                    turtas      ru       58        58          48
# 5789                baruun-urt      mn       46        46          79
# 3600                   kaiyuan      cn       42        42          65
# 1526               campo maior      br       39        39          57
# 6836              zlatoustovsk      ru
# 6528                    ulagan      ru       50        50          61
# 5337         elk grove village      us       42        42          72
# 5940                  enumclaw      us       47        47          53
# 7390         zheleznodorozhnyy      ru       55        55          65
# 2395           san benito abad      co        8         8          76
# 956                 pedra azul      br      -16       -16          55
# 6944                  kommunar      ru       59        59          64
# 2088                   cayenne      gf        4         4          73
# 267                villa maria      ar        4         4          55
# 7020                   stupino      ru       54        54          64
# 2963                   mangrol      in       25        25         101
# 5181                   fengrun      cn       39        39          84
# 174        veinticinco de mayo      ar      -27       -27          64
# 7245     ilinskoye-khovanskoye      ru       56        56          69
# 3663                   ahraura      in       25        25         100
# 5795               shuangcheng      cn       45        45          71
# 7150            nizhniy ufaley      ru       55        55          48
# 393                cerro largo      br      -28       -28          63
# 2562                  petatlan      mx       17        17          78
# 4966                   gardner      us       38        38          70
# 4335                      kusk      af
#
#      humidity cloudiness wind_speed
# 2252       88         20          2
# 6685       54          0          8
# 4841       30          1          3
# 2065       74         75          4
# 7627       30         80          3
# 7908       94         68          3
# 2087      100         75          2
# 4774
# 5837       63          1          6
# 579        68         48          7
# 2724
# 5877       88          0          4
# 533        27          0         21
# 7885      100         80          5
# 2292       80         12          9
# 3553       88          0          4
# 6938       53         36         13
# 6671       55          0          3
# 3849       84         32          8
# 315        70          0          3
# 5499       68          0          3
# 6435       61         75         13
# 1618       80          0          2
# 2789       90         88         11
# 7482       41         36          4
# 2846       87          0          6
# 1577       27          0          4
# 3269       76          0          1
# 2011      100         88          8
# 4982      100         90          5
# ...       ...        ...        ...
# 5495       94         68          1
# 5046
# 1938       75         44          2
# 716        70          0         20
# 7471       47         44          6
# 5789       39          0          8
# 3600       98         36          4
# 1526       87         75          6
# 6836
# 6528       26         24          2
# 5337       82          1          5
# 5940       66          1          3
# 7390       59          0         13
# 2395      100         76          3
# 956        96          8          4
# 6944       39          0         13
# 2088      100         75          2
# 267        93         75          3
# 7020       59          0         13
# 2963       27         44          9
# 5181       44          0          4
# 174        66         48          8
# 7245       45         48         24
# 3663       42          0         10
# 5795       37          0          6
# 7150       67         48          7
# 393        63         20         12
# 2562      100          0          2
# 4966       93         90         20
# 4335
#
# [500 rows x 8 columns]

# %%
# import datetime
# date = datetime.date.today()
import time
date = time.strftime("%m/%d/%Y")
# print(date)
plt.scatter(samplecity['latitude'],samplecity['temperature'])
plt.title(f"Temperature (F) vs. Latitude {date}")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.style.use('ggplot')
plt.savefig("Temperature.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-e171a875c7aa> in <module>()
#       4 date = time.strftime("%m/%d/%Y")
#       5 # print(date)
# ----> 6 plt.scatter(samplecity['latitude'],samplecity['temperature'])
#       7 plt.title(f"Temperature (F) vs. Latitude {date}")
#       8 plt.xlabel("Latitude")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3376                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3377                          linewidths=linewidths, verts=verts,
# -> 3378                          edgecolors=edgecolors, data=data, **kwargs)
#    3379     finally:
#    3380         ax._hold = washold
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4030                 offsets=offsets,
#    4031                 transOffset=kwargs.pop('transform', self.transData),
# -> 4032                 alpha=alpha
#    4033                 )
#    4034         collection.set_transform(mtransforms.IdentityTransform())
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\collections.py in __init__(self, paths, sizes, **kwargs)
#     876         """
#     877
# --> 878         Collection.__init__(self, **kwargs)
#     879         self.set_paths(paths)
#     880         self.set_sizes(sizes)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     147         self._uniform_offsets = None
#     148         if offsets is not None:
# --> 149             offsets = np.asanyarray(offsets, float)
#     150             # Broadcast (2,) -> (1, 2) but nothing else.
#     151             if offsets.shape == (2,):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\numpy\core\numeric.py in asanyarray(a, dtype, order)
#     542
#     543     """
# --> 544     return array(a, dtype, copy=False, order=order, subok=True)
#     545
#     546
#
# ValueError: could not convert string to float:
