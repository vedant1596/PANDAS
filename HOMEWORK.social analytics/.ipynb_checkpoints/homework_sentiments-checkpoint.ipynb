# %%
#Dependencies
import tweepy
import json
import pandas as pd
import numpy as np
import time
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
#Twitter API keys

from keys import (consumer_key, 
                    consumer_secret, 
                    access_token, 
                    access_token_secret)



auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
#Get tweets from each news organization's twitter feeds.



# A list to hold sentiments.

sentiments = []

target_users = ("@BBC", "@CBS", "@CNN", "@FoxNews", "@NYTimes")

#Loop though target users.

for user in target_users:
    
    #Counter 

    counter = 0
    
    #Loop through 5 pages of tweets for each news organization.


    #Get all tweets from the homefeed of each news organization.

    public_tweets = api.user_timeline(user, count = 100)

        #Loop through all tweets.

    for tweet in public_tweets:

        #Run the Vader analysis on each tweet.

        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        tweet_text = tweet["text"]

        #Add sentiments for each tweet to the sentiments list.
        
        
        sentiments.append({"User" : user,
                           "Date": tweet["created_at"],
                           "Compound" : compound,
                           "Positive" : pos,
                           "Negative" : neg,
                           "Neutral" : neu,
                           "Tweets Ago" : counter,
                           "Tweet Text" : tweet_text})
        #Add to counter.

        counter = counter + 1

# %%
news_sentiments = pd.DataFrame.from_dict(sentiments)
news_sentiments
# Out:
#      Compound                            Date  Negative  Neutral  Positive  \
# 0     -0.5719  Sun Jun 10 19:04:08 +0000 2018     0.239    0.761     0.000
# 1      0.4588  Sun Jun 10 18:02:27 +0000 2018     0.000    0.880     0.120
# 2      0.0000  Sun Jun 10 17:03:05 +0000 2018     0.000    1.000     0.000
# 3      0.0000  Sun Jun 10 16:02:05 +0000 2018     0.000    1.000     0.000
# 4      0.6808  Sun Jun 10 15:22:00 +0000 2018     0.000    0.804     0.196
# 5      0.7003  Sun Jun 10 15:19:47 +0000 2018     0.000    0.799     0.201
# 6     -0.2500  Sun Jun 10 15:01:05 +0000 2018     0.236    0.610     0.154
# 7      0.0000  Sun Jun 10 14:38:18 +0000 2018     0.000    1.000     0.000
# 8      0.5719  Sun Jun 10 14:37:55 +0000 2018     0.000    0.861     0.139
# 9     -0.4215  Sun Jun 10 13:02:07 +0000 2018     0.256    0.600     0.144
# 10     0.5719  Sun Jun 10 12:12:42 +0000 2018     0.000    0.861     0.139
# 11     0.0000  Sun Jun 10 12:02:04 +0000 2018     0.000    1.000     0.000
# 12     0.0000  Sun Jun 10 10:58:07 +0000 2018     0.000    1.000     0.000
# 13    -0.3818  Sun Jun 10 10:28:00 +0000 2018     0.120    0.880     0.000
# 14     0.5719  Sun Jun 10 10:11:08 +0000 2018     0.000    0.861     0.139
# 15    -0.4588  Sun Jun 10 10:01:05 +0000 2018     0.227    0.625     0.148
# 16     0.0000  Sun Jun 10 09:01:05 +0000 2018     0.000    1.000     0.000
# 17     0.0000  Sun Jun 10 08:01:04 +0000 2018     0.000    1.000     0.000
# 18     0.9134  Sun Jun 10 07:03:02 +0000 2018     0.067    0.491     0.442
# 19     0.0000  Sat Jun 09 20:04:00 +0000 2018     0.000    1.000     0.000
# 20     0.3612  Sat Jun 09 19:02:05 +0000 2018     0.000    0.878     0.122
# 497    0.8074  Sat Jun 09 23:43:28 +0000 2018     0.000    0.722     0.278
# 498   -0.4019  Sat Jun 09 23:43:02 +0000 2018     0.130    0.870     0.000
# 499   -0.6705  Sat Jun 09 23:25:30 +0000 2018     0.647    0.353     0.000
#
#                                             Tweet Text  Tweets Ago      User
# 0    As the Poldarks look to rebuild their marriage...           0      @BBC
# 1    Can we interest you in a little cockroach milk...           1      @BBC
# 2    Emily Davison became a martyr to the suffraget...           2      @BBC
# 3    Little girls don’t stay little forever. https:...           3      @BBC
# 4    RT @BBCOne: "We are woman, we have loud voices...           4      @BBC
# 5    RT @BBCOne: Women across the UK are marching t...           5      @BBC
# 6    Is feminism actually just a war on men? @Rache...           6      @BBC
# 7    RT @CBeebiesHQ: Would you consider an alternat...           7      @BBC
# 8    RT @BBCOne: We're celebrating female voices an...           8      @BBC
# 9    ⚒🎬 @chrishemsworth returns as the hammer-wield...           9      @BBC
# 10   RT @bbcarts: 100 years after the Suffragettes ...          10      @BBC
# 11   Kirsty Young presents live coverage of the pro...          11      @BBC
# 12   Can you believe these wonders are beneath UK w...          12      @BBC
# 13   In 1913, Emily Wilding Davison made the ultima...          13      @BBC
# 14   RT @BBCTwo: We're celebrating female voices an...          14      @BBC
# 15   Learning to embrace that sinking, nagging feel...          15      @BBC
# 16   How the suffragettes woke us up. https://t.co/...          16      @BBC
# 17   ❤️ The moment actor Maisie Sly, who's deaf, fi...          17      @BBC
# 18   This elderly man was struggling slowly across ...          18      @BBC
# 19   Would you describe yourself as a feminist?\n#H...          19      @BBC
# 20   What is it like being Germaine Greer? This obs...          20      @BBC
# 21   The cast of @QueerEye brought a bag of goodies...          21      @BBC
# 22   One hundred years after some women won the rig...          22      @BBC
# 23   A year on from the Grenfell Tower fire, Sean a...          23      @BBC
# 24   One shocking day of sexual violence from the p...          24      @BBC
# 25   ❤️️ This is what love looks like. https://t.co...          25      @BBC
# 26   😆 @ChanningTatum and @UsainBolt have all the m...          26      @BBC
# 27   Fifty nations are now taking action to reduce ...          27      @BBC
# 28   RT @BBCNews: The Royal family watch the RAF fl...          28      @BBC
# 29   Your friend that likes gin will LOVE this. #To...          29      @BBC
# ..                                                 ...         ...       ...
# 470  Even though the 7-Minute Workout sounds easy, ...          70  @NYTimes
# 471  RT @NYTSports: After losing to Simona Halep in...          71  @NYTimes
# 472  The New York Times obituary for Anthony Bourda...          72  @NYTimes
# 473  Why Guatemala’s volcano has been more deadly t...          73  @NYTimes
# 474  Corruption Gutted South Africa’s Tax Agency. N...          74  @NYTimes
# 475  "I think it is a wonderful thing that poets ar...          75  @NYTimes
# 476  Giant salamander farms in China "are driving t...          76  @NYTimes
# 477  Rachel Cusk's novels describe what it’s like t...          77  @NYTimes
# 478  Maria Bueno, Brazilian Tennis Star Who Reigned...          78  @NYTimes
# 479  President Macron of France said the trade deba...          79  @NYTimes
# 480  For 6 straight World Cups, Mexico has cheered ...          80  @NYTimes
# 481  What is the trade deficit? It’s not a scorecar...          81  @NYTimes
# 482  RT @nytlizrobbins: Pablo Villavicencio, arrest...          82  @NYTimes
# 483  Anthony Bourdain understood that eating was si...          83  @NYTimes
# 484  RT @peterbakernyt: With a petulant tweetstorm ...          84  @NYTimes
# 485  On Horse Racing: At 52, Mike Smith Has the Rid...          85  @NYTimes
# 486  RT @amyvirshup: Kris Kobach email in group of ...          86  @NYTimes
# 487  Before leaving the annual meeting of major wor...          87  @NYTimes
# 488  Documents Show Political Lobbying in Census Qu...          88  @NYTimes
# 489  Venomous stonefish are ugly, and they're poiso...          89  @NYTimes
# 490  Trudeau’s office responded to Trump's tweets w...          90  @NYTimes
# 491  The ice over Manhattan would have buried even ...          91  @NYTimes
# 492  Trudeau sought to play down personal clashes w...          92  @NYTimes
# 493  Nick Cave Wants You to Work It Out on the Danc...          93  @NYTimes
# 494  Janelle Monáe brings a pair of big fuzzy socks...          94  @NYTimes
# 495  RT @kimseverson: Here's a sketch of Bourdain’s...          95  @NYTimes
# 496  Judge Stops Deportation of a New York Pizza De...          96  @NYTimes
# 497  RT @nytimestravel: This year would have been L...          97  @NYTimes
# 498  Breaking News: President Trump upended two day...          98  @NYTimes
# 499  I Have Post-Brokeness Stress Disorder https://...          99  @NYTimes
#
# [500 rows x 8 columns]

# %%
#Export the DataFrame to as csv.

news_sentiments.to_csv("Twitter_News_Mood.csv", index=False)

# %%
#Plot scatterplot graph.

# Set the x limit,
plt.xlim(101, -1)

#plot scatterplot using a for loop.
for user in target_users:
    dataframe = news_sentiments.loc[news_sentiments["User"] == user]
    plt.scatter(dataframe["Tweets Ago"],dataframe["Compound"],label = user)
    
#Add legend
plt.legend(bbox_to_anchor = (1,1))

#Add title, x axis label, and y axis label.
plt.title("Sentiment Analysis of Media Tweets (06/10/2018)")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")

#Set a grid on the plot.
plt.grid()

plt.savefig("Sentiment Analysis of Media Tweets")
plt.show()

# %%
average_sentiment = news_sentiments.groupby("User")["Compound"].mean()
average_sentiment
# Out:
# User
# @BBC        0.138191
# @CBS        0.328034
# @CNN        0.029527
# @FoxNews   -0.105961
# @NYTimes    0.083528
# Name: Compound, dtype: float64

# %%
x_axis = np.arange(len(average_sentiment))
xlabels = average_sentiment.index
count = 0
for sentiment in average_sentiment:
    plt.text(count, sentiment+.01, str(round(sentiment,2)))
    count = count + 1
plt.bar(x_axis, average_sentiment, tick_label = xlabels, color = ["aqua", 'g', 'r', 'b', 'y'])
#Set title, x axis label, and y axis label.
plt.title("Overall Sentiment of Media Tweets (06/10/2018)")
plt.xlabel("New Organizations")
plt.ylabel("Tweet Polarity")
plt.savefig("Overall Sentiment of Media Tweets")
plt.show()

# %% [markdown]
# # Analysis
#
# 1. Fox News had the most negative Vader sentiment analysis.
#
# 2. The New York Times and CNN had Positive score slightly higher thann O , which showsthey are the news outlet with the closest    to neutral sentiment.
#
# 3. While both the BBC and CBS had an overall positive Vader scores CBS had the highest score with 0.2. the BBC had 0.09.
#
# 4. The validity of the Vader analysis is questionable. There are tweets of negative events that have neutral Vader scores          instead of expected negative Vader scores.
#
# 5. The Vader analysis on news organizations is highly dependent on the type of news happens on a particular day. A more fair        analysis would analyze a larger sample of tweets over a larger period of time.
